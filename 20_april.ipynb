# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tkinter import *
from PIL import Image,ImageTk
from tkinter import messagebox

# %%
win=Tk()
win.geometry("500x600")
b1=Button(win,text="button1")
b2=Button(win,text="button2")
b3=Button(win,text="button3")
b4=Button(win,text="button4")
b5=Button(win,text="button5")
b6=Button(win,text="button6")
b1.grid(row=0,column=0,padx=10)
b2.grid(row=0,column=1)
b3.grid(row=0,column=2,padx=10)
b4.grid(row=1,column=0)
b5.grid(row=1,column=1)
b6.grid(row=1,column=2)

win.mainloop()

# %%
win=Tk()
win.geometry("500x600")

frm=Frame(win)
#frm.configure(bg='gray')
frm.place(x=100,y=200,width=250,height=100)

b1=Button(frm,text="button1")
b2=Button(frm,text="button2")
b3=Button(frm,text="button3")
b4=Button(frm,text="button4")
b5=Button(frm,text="button5")
b6=Button(frm,text="button6")
b1.grid(row=0,column=0,padx=10)
b2.grid(row=0,column=1)
b3.grid(row=0,column=2,padx=10)
b4.grid(row=1,column=0)
b5.grid(row=1,column=1)
b6.grid(row=1,column=2)
win.mainloop()

# %%
win=Tk()
win.state('zoomed')
win.configure(bg='powder blue')

frm =Frame(win)
frm.configure(bg='pink')
frm.place(x=0,y=0,relwidth=1,relheight=.2)

lbl_title=Label(frm,text="INDIA",font=('',50,'bold','underline'),bg='pink')
lbl_title.pack()

img=Image.open("d:/images/flag.jpg")
tk_img=ImageTk.PhotoImage(img.resize((150,150)))
lbl_img=Label(frm,image=tk_img)
lbl_img.place(x=0,y=0,width=150,height=150)
win.mainloop()

# %%
win=Tk()
win.state('zoomed')

img_bg=Image.open("d:/images/bgg.jpg")
tk_imgbg=ImageTk.PhotoImage(img_bg.resize((1200,800)))
lbl_bg=Label(win,image=tk_imgbg)
lbl_bg.place(x=0,y=0)

frm =Frame(win)
frm.configure(bg='pink')
frm.place(x=0,y=0,relwidth=1,relheight=.2)

lbl_title=Label(frm,text="INDIA",font=('',50,'bold','underline'),bg='pink')
lbl_title.pack()

img=Image.open("d:/images/flag.jpg")
tk_img=ImageTk.PhotoImage(img.resize((150,150)))
lbl_img=Label(frm,image=tk_img)
lbl_img.place(x=0,y=0,width=150,height=150)
win.mainloop()

# %%
def welcome():
    win=Tk()
    win.state('zoomed')
    win.configure(bg='red')
    win.mainloop()
    
def check():
    u=e_u.get()
    p=e_p.get()
    if(len(u)==0 or len(p)==0):
        messagebox.showwarning('validation','Empty fields are not allowed')
    else:
        if(u=='admin' and p=='admin'):
            #messagebox.showinfo('auth','valid user')
            welcome()
        else:
            messagebox.showerror('auth','invalid user')
win=Tk()
win.state('zoomed')
win.configure(bg='powder blue')

frm =Frame(win)
frm.configure(bg='pink')
frm.place(x=0,y=0,relwidth=1,relheight=.2)

lbl_title=Label(frm,text="INDIA",font=('',50,'bold','underline'),bg='pink')
lbl_title.pack()

frm2 =Frame(win)
frm2.configure(bg='powder blue')
frm2.place(relx=.3,rely=.4,width=500,height=200)

lbl_u=Label(frm2,text="Username:",font=('',20),bg='powder blue')
lbl_p=Label(frm2,text="Password:",font=('',20),bg='powder blue')
lbl_u.place(x=0,y=0)
lbl_p.place(x=0,y=50)

e_u=Entry(frm2,font=('',20),bd=5)
e_p=Entry(frm2,font=('',20),bd=5,show='*')
e_u.place(x=150,y=0)
e_p.place(x=150,y=50)

btn=Button(frm2,text="Submit",font=('',20),bd=5,command=check)
btn.place(x=200,y=120)
win.mainloop()

# %%
def first_screen():
    frm2 =Frame(win)
    frm2.configure(bg='powder blue')
    frm2.place(relx=.3,rely=.4,width=500,height=200)

    lbl_u=Label(frm2,text="Username:",font=('',20),bg='powder blue')
    lbl_p=Label(frm2,text="Password:",font=('',20),bg='powder blue')
    lbl_u.place(x=0,y=0)
    lbl_p.place(x=0,y=50)

    global e_u,e_p
    
    e_u=Entry(frm2,font=('',20),bd=5)
    e_p=Entry(frm2,font=('',20),bd=5,show='*')
    e_u.place(x=150,y=0)
    e_p.place(x=150,y=50)

    btn=Button(frm2,text="Submit",font=('',20),bd=5,command=check)
    btn.place(x=200,y=120)

def welcome():
    frm2 =Frame(win)
    frm2.configure(bg='red')
    frm2.place(relx=0,rely=.2,relwidth=1,relheight=.8)
    
def check():
    u=e_u.get()
    p=e_p.get()
    if(len(u)==0 or len(p)==0):
        messagebox.showwarning('validation','Empty fields are not allowed')
    else:
        if(u=='admin' and p=='admin'):
            #messagebox.showinfo('auth','valid user')
            welcome()
        else:
            messagebox.showerror('auth','invalid user')

win=Tk()
win.state('zoomed')
win.configure(bg='powder blue')

frm =Frame(win)
frm.configure(bg='pink')
frm.place(x=0,y=0,relwidth=1,relheight=.2)

lbl_title=Label(frm,text="INDIA",font=('',50,'bold','underline'),bg='pink')
lbl_title.pack()
first_screen()
win.mainloop()

# %%
def check(event):
    u=e_u.get()
    p=e_p.get()
    if(len(u)==0 or len(p)==0):
        messagebox.showwarning('validation','Empty fields are not allowed')
    else:
        if(u=='admin' and p=='admin'):
            messagebox.showinfo('auth','valid user')
        else:
            messagebox.showerror('auth','invalid user')
win=Tk()
win.state('zoomed')
win.configure(bg='powder blue')

frm =Frame(win)
frm.configure(bg='pink')
frm.place(x=0,y=0,relwidth=1,relheight=.2)

lbl_title=Label(frm,text="INDIA",font=('',50,'bold','underline'),bg='pink')
lbl_title.pack()

frm2 =Frame(win)
frm2.configure(bg='powder blue')
frm2.place(relx=.3,rely=.4,width=500,height=200)

lbl_u=Label(frm2,text="Username:",font=('',20),bg='powder blue')
lbl_p=Label(frm2,text="Password:",font=('',20),bg='powder blue')
lbl_u.place(x=0,y=0)
lbl_p.place(x=0,y=50)

e_u=Entry(frm2,font=('',20),bd=5)
e_p=Entry(frm2,font=('',20),bd=5,show='*')
e_u.place(x=150,y=0)
e_p.place(x=150,y=50)

btn=Button(frm2,text="Submit",font=('',20),bd=5)
btn.bind('<Button>',check)

btn.place(x=200,y=120)
win.mainloop()
