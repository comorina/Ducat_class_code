# %%
file=open("abc.txt","w")
file.write("this is python language")
file.write("\n")
file.write("bharat")
#file.write(100)
file.write(str(100))
#file.flush()
file.close() #internally calls flush()

# %%
file=open("abc.txt","a")
file.write("\nind v/s eng 2nd ODI")
file.close()

# %%
file=open("d:/mylog.txt","a")
print("apple")
print("mango")
from datetime import datetime
dt=datetime.now()
file.write(str(dt))
file.write("\n-----------\n")
file.close()
# Out:
# apple
# mango

# %%
file=open("xyz.txt","x") #exclusive write
file.write("hello")
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-6-f672097473b8> in <module>
# ----> 1 file=open("xyz.txt","x") #exclusive write
#       2 file.write("hello")
#       3 file.close()
#
# FileExistsError: [Errno 17] File exists: 'xyz.txt'

# %%
file=open("d:/msg.txt","r+") #read then write
text=file.read()
print(text)
file.write("this is python")
file.close()
# Out:
# hi
# hello
# bye

# %%
file=open("d:/msg.txt","w+") #write then read
file.write("hi...")
file.seek(0)
text=file.read()
print(text)
file.close()
# Out:
# hi...

# %%
file=open("d:/images/flag.jpg","rb")
x=file.read()
print(type(x))
print(x[0],x[1])
file.close()
# Out:
# <class 'bytes'>
# 255 216

# %%
file=open("flag.jpg","wb")
file.write(x)
file.close()

# %%
file=open("d:/dataset/docx_files/abc.docx","rb")
data=file.read()
print(data)
file.close()
# Out:
# b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\x04{\xc5R\xed\x01\x00\x00d\n\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(\x0
# ...

# %%
pip install docxpy
# Out:
# ...
#   Created wheel for docxpy: filename=docxpy-0.8.5-py3-none-any.whl size=4986 sha256=07e42422bfc78c50833530abcdc7c42134c5dcde00401ece6089eff7e33499aa
#   Stored in directory: c:\users\ducat\appdata\local\pip\cache\wheels\e5\f5\4b\ee4a91effc36ffdf859cb70cdb6821459aeee09296c5306b0a
# Successfully built docxpy
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import docxpy

# %%
text=docxpy.process("d:/dataset/docx_files/abc.docx")
print(text)
# Out:
# ASSIGNMENT
#
#
#
# WAP to print all even and odd numbers between 1 and 100 python;
#
# WAP to print all even and odd numbers between 100 and 1;
#
# WAP to print sum of numbers from 1 and 100;
#
# WAP to print sum of the following series: +++…..+;
#
# WAP to print  calculate the factorial of number entered through keyboard;
#
# WAP to print the following triangle:
#
#    	1
#
#                                  2       	3
#
#                    4            5        	6
#
# WAP to print the following triangle:
#
# *
#
#          *     *         *
#
#     *        *          *        *        *
#
#
#
# WAP to print the following triangle:
#
# 1  2  3  4  5
#
# 1  2  3  4
#
# 1  2  3
#
# 1  2
#
# 1
#
# WAP to print the following triangle:
#
#          1
#
#          2      2
#
#          3      3    3
#
#          4      4    4      4
#
# WAP to print the following Pattern.
#
# A B C D E F G F E D C B A
#
# A B C D E F   F E D C B A
#
# A B C D E       E D C B A
#
# ...

# %%
import re

# %%
text="Python Is a Funny Language created by Rossum in 1991 @ CWI."

# %%
#itr=re.finditer(".[aeiou]",text)
#itr=re.finditer(".[aeiou]",text,re.I)
#itr=re.finditer("[a-z][aeiou][a-z]",text,re.I)
#itr=re.finditer("[a-zA-Z][aeiou][a-z]",text)
#itr=re.finditer("[0-9]",text)
#itr=re.finditer("[0-9][0-9]",text)
#itr=re.finditer("\.",text)
#itr=re.finditer("\d",text)
#itr=re.finditer("\D",text)
#itr=re.finditer("\s",text)
#itr=re.finditer("\S",text)
#itr=re.finditer("\w",text)
#itr=re.finditer("\W",text)
#itr=re.finditer("[a-z][a-z][a-z][a-z]",text)
#itr=re.finditer("[a-z]{4}",text)
#itr=re.finditer(".[a-z]{4}",text)
#itr=re.finditer("[a-z]{2,4}",text)
#itr=re.finditer("[a-z]*",text)
#itr=re.finditer("[a-z]+",text)
itr=re.finditer("[a-z]?",text)

for match in itr:
    print(match)
    #print(match.group(),match.start(),match.end(),match.span())
# Out:
# <re.Match object; span=(0, 0), match=''>
# <re.Match object; span=(1, 2), match='y'>
# <re.Match object; span=(2, 3), match='t'>
# <re.Match object; span=(3, 4), match='h'>
# <re.Match object; span=(4, 5), match='o'>
# <re.Match object; span=(5, 6), match='n'>
# <re.Match object; span=(6, 6), match=''>
# <re.Match object; span=(7, 7), match=''>
# <re.Match object; span=(8, 9), match='s'>
# <re.Match object; span=(9, 9), match=''>
# <re.Match object; span=(10, 11), match='a'>
# <re.Match object; span=(11, 11), match=''>
# <re.Match object; span=(12, 12), match=''>
# <re.Match object; span=(13, 14), match='u'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='n'>
# <re.Match object; span=(16, 17), match='y'>
# <re.Match object; span=(17, 17), match=''>
# <re.Match object; span=(18, 18), match=''>
# <re.Match object; span=(19, 20), match='a'>
# <re.Match object; span=(20, 21), match='n'>
# <re.Match object; span=(21, 22), match='g'>
# ...
